# %% [markdown]
# ## Open Government Data, provided by **Statistisches Amt des Kantons Basel-Stadt - Fachstelle OGD**
# *Autogenerated Python starter code for data set with identifier* **100384**

# %% [markdown]
# ## Dataset
# # **Zeitreihe der Temperaturen der Gartenbäder**

# %% [markdown]
# ## Data set links
#
# [Direct data shop link for dataset](https://data.bs.ch/explore/dataset/100384)

# %% [markdown]
# ## Metadata
# - **Dataset_identifier** `100384`
# - **Title** `Zeitreihe der Temperaturen der Gartenbäder`
# - **Description** `<p style='font-family: sans-serif;'>Dieser Datensatz enthält eine kontinuierliche Aufzeichnung der Wassertemperaturen in den Gartenbädern, beginnend ab dem 16. August 2024.</p><p style='font-family: sans-serif;'>Die Temperaturdaten werden alle 15 Minuten aktualisiert, indem ein automatisiertes Programm die neuesten Werte von der Webseite <a href='https://www.ed-baeder.ch/' target='_blank'>https://www.ed-baeder.ch/</a> abruft. Auf dieser Webseite findet man auch sonstige Meldungen zu den Gartenbädern.</p><p style='font-family: sans-serif;'>Falls ein Gartenbad geschlossen ist oder keine Temperaturmessung verfügbar ist, wird für diesen Zeitraum kein Wert im Datensatz vermerkt.</p><p style='font-family: sans-serif;'><span style='font-weight: bolder;'>Weiterführende Links:</span></p><p style='font-family: sans-serif;'>Weitere Informationen zu den Gartenbädern: <a href='https://www.bs.ch/themen/kultur-sport-und-freizeit/baeder-kunsteisbahnen-sportanlagen-und-raeume/gartenbaeder-basel' target='_blank'>https://www.bs.ch/themen/kultur-sport-und-freizeit/baeder-kunsteisbahnen-sportanlagen-und-raeume/gartenbaeder-basel</a></p><p style='font-family: sans-serif;'>Aktuelle Temperaturen der Gartenbäder als Datensatz: <a href='https://data.bs.ch/explore/dataset/100384/' target='_blank'>https://data.bs.ch/explore/dataset/100384/</a></p><p style='font-family: sans-serif;'>Diese und weitere Sportanlagen als Datensatz: <a href='https://data.bs.ch/explore/dataset/100151/' target='_blank'>https://data.bs.ch/explore/dataset/100151/</a></p>`
# - **Contact_name** `Fachstelle für OGD Basel-Stadt`
# - **Issued** `2024-08-16`
# - **Modified** `2025-02-13T06:46:15+00:00`
# - **Rights** `NonCommercialAllowed-CommercialAllowed-ReferenceRequired`
# - **Temporal_coverage_start_date** `2024-08-15T22:00:00+00:00`
# - **Temporal_coverage_end_date** `2025-02-12T23:00:00+00:00`
# - **Themes** `['Kultur, Medien, Informationsgesellschaft, Sport', 'Tourismus']`
# - **Keywords** `['Hallenbad', 'Familienbad', 'Sportbad', 'behindertengerecht', 'Schwimmzone', 'Schwimmen', 'Baden', 'OpenSportData']`
# - **Publisher** `Jugend, Familie und Sport`
# - **Reference** `https://www.bs.ch/themen/kultur-sport-und-freizeit/baeder-kunsteisbahnen-sportanlagen-und-raeume/gartenbaeder-basel`

# %% [markdown]
# ## Imports and helper functions

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('ggplot')

params = {
    'text.color': (0.25, 0.25, 0.25),
    'figure.figsize': [18, 6],
   }

plt.rcParams.update(params)

import pandas as pd
import requests
import os

# %%
# helper function for reading datasets with proper separator
def get_dataset(url):
    r = requests.get(url, params={'format': 'csv', 'timezone': 'Europe%2FZurich'})
    data_path = os.path.join(os.getcwd(), '..', 'data')
    if not os.path.exists(data_path):
      os.makedirs(data_path)
    csv_path = os.path.join(data_path, '100384.csv')
    with open(csv_path, 'wb') as f:
        f.write(r.content)
    data = pd.read_csv(url, sep=';', on_bad_lines='warn', encoding_errors='ignore', low_memory=False)
    # if dataframe only has one column or less the data is not ";" separated
    if data.shape[1] <= 1:
        print("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
    return data

# %% [markdown]
# ## Load data
#
# The dataset is read into a dataframe

# %%
df = get_dataset('https://data.bs.ch/explore/dataset/100384/download')

# %% [markdown]
# ## Analyze data

# %%
# drop columns that have no values
df.dropna(how='all', axis=1, inplace=True)

# %%
print(f'The dataset has {df.shape[0]:,.0f} rows (observations) and {df.shape[1]:,.0f} columns (variables).')
print(f'There seem to be {df.duplicated().sum()} exact duplicates in the data.')

# %%
df.info(memory_usage='deep', verbose=True)

# %%
df.head()

# %%
# display a small random sample transposed in order to see all variables
df.sample(3).T

# %%
# describe non-numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(exclude='number'))
except:
    print("No categorical data in dataset.")

# %%
# describe numerical features
try:
    with pd.option_context('display.float_format', '{:,.2f}'.format):
        display(df.describe(include='number'))
except:
    print("No numercial data in dataset.")

# %%
# check missing values with missingno
# https://github.com/ResidentMario/missingno
import missingno as msno
msno.matrix(df, labels=True, sort='descending');

# %%
# plot a histogram for each numerical feature
try:
    df.hist(bins=25, rwidth=.9)
    plt.tight_layout()
    plt.show()
except:
    print("No numercial data to plot.")

# %%
# continue your code here...

# %% [markdown]
# **Questions about the data?** Fachstelle für OGD Basel-Stadt | opendata@bs.ch
