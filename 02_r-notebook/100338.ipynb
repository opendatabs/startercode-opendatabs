# %% [markdown]
# ## Open Government Data, provided by **Statistisches Amt des Kantons Basel-Stadt - Fachstelle OGD**
# date: 2024-09-14

# %% [markdown]
# ## Dataset
# # **Resultate der Ersatzwahl Regierungspräsidium 3. März 2024**

# %% [markdown]
# ## Data set links
#
# [Direct data shop link for dataset](https://data.bs.ch/explore/dataset/100338)

# %% [markdown]
# *Autogenerated Python starter code for data set with identifier* **100338**

# %% [markdown]
# ## Metadata
# - **Dataset_identifier** `100338`
# - **Title** `Resultate der Ersatzwahl Regierungspräsidium 3. März 2024`
# - **Description** `<p class='MsoNormal' style='font-family: sans-serif;'>Dieser Datensatz zeigt die Resultate des ersten Wahlgangs der Regierungspräsidiums-Ersatzwahl vom 3. März 2024.</p><p style='font-family: sans-serif;'></p><p class='MsoNormal' style='font-family: sans-serif;'>Bitte beachten Sie, dass die offiziell gültigen Schlussresultate im Kantonsblatt des Kantons Basel-Stadt publiziert werden.</p>`
# - **Contact_name** `Fachstelle für OGD Basel-Stadt`
# - **Issued** `2024-03-02`
# - **Modified** `2024-04-07T14:15:56+00:00`
# - **Rights** `NonCommercialAllowed-CommercialAllowed-ReferenceRequired`
# - **Temporal_coverage_start_date** `None`
# - **Temporal_coverage_end_date** `None`
# - **Themes** `['Politik', 'Bevölkerung']`
# - **Keywords** `['Wahlen', 'Mitbestimmung', 'Regierung', 'Exekutive', 'Teilhabe', 'Demokratie', 'Ersatzwahl', 'Erster Wahlgang']`
# - **Publisher** `Staatskanzlei`
# - **Reference** `https://www.staatskanzlei.bs.ch/politische-rechte/wahlen-abstimmungen/ersatzwahl-rr-rrp.html`

# %% [markdown]
# # Load packages

# %%
library(tidyverse)

# %% [markdown]
# # Load data
# The dataset is read into a dataframe

# %%
get_dataset <- function(url) {
  # Create directory if it does not exist
  data_path <- file.path(getwd(), '..', 'data')
  if (!dir.exists(data_path)) {
    dir.create(data_path, recursive = TRUE)
  }
  # Download the CSV file
  csv_path <- file.path(data_path , '100338.csv')
  download.file(url, csv_path, mode = "wb")

  # Read the CSV file
  data <- tryCatch(
      read.csv(csv_path, sep = ";", stringsAsFactors = FALSE, encoding = "UTF-8"),
      warning = function(w) NULL,
      error = function(e) NULL
  )
  # if dataframe only has one column or less the data is not ";" separated
  if (is.null(data) || ncol(data) <= 1) {
      stop("The data wasn't imported properly. Very likely the correct separator couldn't be found.\nPlease check the dataset manually and adjust the code.")
  }
  return(data)
}

# %%
df = get_dataset('https://data.bs.ch/explore/dataset/100338/download')

# %% [markdown]
# # Analyze data

# %%
glimpse(df)

# %%
str(df)

# %%
head(df)

# %%
tail(df)

# %%
# Remove columns that have no values
df <- Filter(function(x) !all(is.na(x)), df)

# Remove rows with missing values (if appropriate)
df <- na.omit(df)

# %%
# display a small random sample transposed in order to see all variables
t(sample_n(df, 5))

# %%
# the size of the data frame in memory
size <- object.size(df)
#  the size in bytes
print(size)

# %%
# describe numerical features
summary(df[, sapply(df, is.numeric)])

# %%
# describe non-numerical features
summary(df[, sapply(df, Negate(is.numeric))])

# %%
# check missing values
df %>%
  mutate(row = row_number()) %>%
  gather(key = "variable", value = "value", -row) %>%
  ggplot(aes(x = variable, y = row)) +
  geom_tile(aes(fill = is.na(value)), color = "black") +
  scale_fill_manual(values = c("TRUE" = "grey", "FALSE" = "red")) +
  labs(x = "", y = "", fill = "Missing") +
  theme(axis.text.x = element_text(angle = 45, hjust = 1))

# %%
# plot a histogram for each numerical feature
df %>%
  select_if(is.numeric) %>%
  gather() %>%
  ggplot( aes(value)) +
  geom_histogram(bins = 10, color = "white", fill = "red") +
    facet_wrap(~key, scales = 'free_x')

# %% [markdown]
# # Continue your code here...

# %% [markdown]
# ------------------------------------------------------------------------

# %% [markdown]
# # Questions about the data?
# Fachstelle für OGD Basel-Stadt | opendata@bs.ch
